# %% [markdown]
# **Broken Link Validator**
#
# **Description:** Checks the validity of URLs in Excel files and classifies them as Working, Redirected, Blocked, or Not working.

# %%
#!pip install requests

# %%
import os  
import pandas as pd  
import requests
from concurrent.futures import ThreadPoolExecutor

# %%
os.chdir(r"C:/Users/mmaha/projects/broken links")

# %%
#os.getcwd()
print(os.listdir())
# Out:
# ['.gitignore.txt', '.ipynb_checkpoints', 'data', 'example.png', 'notebook', 'README.md.txt', 'requirements.txt.txt', 'url_status_2024.xlsx']

# %%
df = pd.read_excel("data/check url status.xls")

# %%
df.tail()
# Out:
#                                                    URL  \
# 774  https://www.indianretailer.com/news/retail-ind...
# 775  https://eu.fdlreporter.com/story/money/2024/05...
# 776  https://chiefswire.usatoday.com/2024/08/23/nc-...
# 777  https://www.energyjobline.com/job/director-sus...
# 778  https://www.cbs17.com/business/press-releases/...
#
#                                                  Title
# 774  Retail India News: Vedix and Shoppers Stop Lau...
# 775  Remember when bowling was a favorite pastime f...
# 776  NC Sportsbook Promos: Best North Carolina Spor...
# 777            Director, Sustainability Reporting APAC
# 778  Military's Leading Foodservice Units Honored f...

# %%
# Function to check URL status
def check_url(URL):
    try:
        response = requests.get(URL, allow_redirects=True, timeout=10)
        if response.status_code == 200:
            return "Working"
        elif response.status_code in [301, 302]:  
            return "Redirected but Working"
        elif response.status_code == 403:  
            return "Blocked (403 Forbidden)"
        else:
            return f"Not Working ({response.status_code})"
    except requests.RequestException as e:
        return f"Not Working ({str(e)})"

# Apply ThreadPoolExecutor for faster execution
with ThreadPoolExecutor(max_workers=10) as executor:
    df['Status'] = list(executor.map(check_url, df['URL']))

# Export to Excel
df.to_excel("data/url_status.xlsx", index=False)

# Print the DataFrame
df
# Out:
#                                                    URL  \
# 0    https://simpleflying.com/how-to-spend-skymiles...
# 1    https://sports.yahoo.com/portugal-route-final-...
# 2    https://indiaeducationdiary.in/anandana-the-co...
# 3    https://www.theringer.com/movies/2024/5/30/241...
# 4    https://www.iracing.com/enascar-coca-cola-irac...
# ..                                                 ...
# 774  https://www.indianretailer.com/news/retail-ind...
# 775  https://eu.fdlreporter.com/story/money/2024/05...
# 776  https://chiefswire.usatoday.com/2024/08/23/nc-...
# 777  https://www.energyjobline.com/job/director-sus...
# 778  https://www.cbs17.com/business/press-releases/...
#
#                                                  Title  \
# 0        5 Ways To Spend Delta SkyMiles Without Flying
# 1    Portugal Route To The Final: Winning start put...
# 2    Anandana- The Coca-Cola India Foundation and I...
# 3        The Postapocalyptic Movie Survivability Index
# 4    eNASCAR Coca-Cola iRacing Series Returns to NA...
# ..                                                 ...
# 774  Retail India News: Vedix and Shoppers Stop Lau...
# 775  Remember when bowling was a favorite pastime f...
# 776  NC Sportsbook Promos: Best North Carolina Spor...
# 777            Director, Sustainability Reporting APAC
# 778  Military's Leading Foodservice Units Honored f...
#
#                       Status
# 0                    Working
# 1                    Working
# 2    Blocked (403 Forbidden)
# 3                    Working
# 4                    Working
# ..                       ...
# 774  Blocked (403 Forbidden)
# 775                  Working
# 776        Not Working (404)
# 777                  Working
# 778  Blocked (403 Forbidden)
#
# [779 rows x 3 columns]

# %% [markdown]
# **ERROR description**
#
# If response.status_code == 200, then the URL is considered "Working" in your script.
#
# 301 Moved Permanently → The URL has changed permanently, and future requests should use the new URL.
#
# 302 Found (Temporary Redirect): The resource is temporarily moved to another location.
#
# HTTP 403 (Forbidden) → "Blocked (403 Forbidden)"
# - Possible causes:
# - Website blocks automated requests (bot protection).
# - Missing authentication or permission.
# - IP restrictions.
#
# 404 Not Found -> The requested URL does not exist.
#
# 500 Internal Server Error -> The server encountered an error.
#
# 405 Method Not Allowed -> The request method is not supported by the server.
#
# 503 Service Unavailable -> The server is down or overloaded.
